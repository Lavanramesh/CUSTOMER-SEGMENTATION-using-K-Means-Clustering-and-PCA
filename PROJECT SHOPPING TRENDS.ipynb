# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder

# %%
df=pd.read_csv(r"C:\Users\91984\Downloads\shopping_table.csv")
df
# Out:
#       Customer_ID  Age  Gender Item_Purchased     Category  \
# 0               1   55    Male         Blouse     Clothing
# 1               2   19    Male        Sweater     Clothing
# 2               3   50    Male          Jeans     Clothing
# 3               4   21    Male        Sandals     Footwear
# 4               5   45    Male         Blouse     Clothing
# ...           ...  ...     ...            ...          ...
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase_Amount_USD       Location Size      Color  Season  \
# 0                      53       Kentucky    L       Gray  Winter
# 1                      64          Maine    L     Maroon  Winter
# ...

# %%
df.head()
# Out:
#    Customer_ID  Age Gender Item_Purchased  Category  Purchase_Amount_USD  \
# 0            1   55   Male         Blouse  Clothing                   53
# 1            2   19   Male        Sweater  Clothing                   64
# 2            3   50   Male          Jeans  Clothing                   73
# 3            4   21   Male        Sandals  Footwear                   90
# 4            5   45   Male         Blouse  Clothing                   49
#
#         Location Size      Color  Season  Review_Rating Subscription_Status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
#   Payment_Method  Shipping_Type Discount_Applied Promo_Code_Used  \
# ...

# %%
df.tail()
# Out:
#       Customer_ID  Age  Gender Item_Purchased     Category  \
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase_Amount_USD    Location Size      Color  Season  Review_Rating  \
# 3895                   28    Virginia    L  Turquoise  Summer            4.2
# 3896                   49        Iowa    L      White  Spring            4.5
# 3897                   33  New Jersey    L      Green  Spring            2.9
# 3898                   77   Minnesota    S      Brown  Summer            3.8
# 3899                   81  California    M      Beige  Spring            3.1
#
#      Subscription_Status Payment_Method   Shipping_Type Discount_Applied  \
# ...

# %% [markdown]
# ## DATA PREPROCESSING

# %%
df.columns
# Out:
# Index(['Customer_ID', 'Age', 'Gender', 'Item_Purchased', 'Category',
#        'Purchase_Amount_USD', 'Location', 'Size', 'Color', 'Season',
#        'Review_Rating', 'Subscription_Status', 'Payment_Method',
#        'Shipping_Type', 'Discount_Applied', 'Promo_Code_Used',
#        'Previous_Purchases', 'Preferred_Payment_Method',
#        'Frequency_of_Purchases'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Customer_ID               3900 non-null   int64
#  1   Age                       3900 non-null   int64
#  2   Gender                    3900 non-null   object
#  3   Item_Purchased            3900 non-null   object
#  4   Category                  3900 non-null   object
#  5   Purchase_Amount_USD       3900 non-null   int64
#  6   Location                  3900 non-null   object
#  7   Size                      3900 non-null   object
#  8   Color                     3900 non-null   object
#  9   Season                    3900 non-null   object
#  10  Review_Rating             3900 non-null   float64
#  11  Subscription_Status       3900 non-null   object
#  12  Payment_Method            3900 non-null   object
# ...

# %%
df.describe()
# Out:
#        Customer_ID          Age  Purchase_Amount_USD  Review_Rating  \
# count  3900.000000  3900.000000          3900.000000    3900.000000
# mean   1950.500000    44.068462            59.764359       3.749949
# std    1125.977353    15.207589            23.685392       0.716223
# min       1.000000    18.000000            20.000000       2.500000
# 25%     975.750000    31.000000            39.000000       3.100000
# 50%    1950.500000    44.000000            60.000000       3.700000
# 75%    2925.250000    57.000000            81.000000       4.400000
# max    3900.000000    70.000000           100.000000       5.000000
#
#        Previous_Purchases
# count         3900.000000
# mean            25.351538
# std             14.447125
# min              1.000000
# 25%             13.000000
# 50%             25.000000
# 75%             38.000000
# max             50.000000

# %%
df.isnull().sum()
# Out:
# Customer_ID                 0
# Age                         0
# Gender                      0
# Item_Purchased              0
# Category                    0
# Purchase_Amount_USD         0
# Location                    0
# Size                        0
# Color                       0
# Season                      0
# Review_Rating               0
# Subscription_Status         0
# Payment_Method              0
# Shipping_Type               0
# Discount_Applied            0
# Promo_Code_Used             0
# Previous_Purchases          0
# Preferred_Payment_Method    0
# Frequency_of_Purchases      0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
## COVERTING CATEGORICAL VARIABLES TO NUMERICAL VARIABLES
df['Gender']=LabelEncoder().fit_transform(df['Gender'])
df
# Out:
#       Customer_ID  Age  Gender Item_Purchased     Category  \
# 0               1   55       1         Blouse     Clothing
# 1               2   19       1        Sweater     Clothing
# 2               3   50       1          Jeans     Clothing
# 3               4   21       1        Sandals     Footwear
# 4               5   45       1         Blouse     Clothing
# ...           ...  ...     ...            ...          ...
# 3895         3896   40       0         Hoodie     Clothing
# 3896         3897   52       0       Backpack  Accessories
# 3897         3898   46       0           Belt  Accessories
# 3898         3899   44       0          Shoes     Footwear
# 3899         3900   52       0        Handbag  Accessories
#
#       Purchase_Amount_USD       Location Size      Color  Season  \
# 0                      53       Kentucky    L       Gray  Winter
# 1                      64          Maine    L     Maroon  Winter
# ...

# %%
print(df['Subscription_Status'].unique())
# Out:
# ['Yes' 'No']

# %%
df['Subscription_Status'] = df['Subscription_Status'].str.strip().str.lower()
df['Subscription_Status']=df['Subscription_Status'].map({'yes':1,'no':0})
df
# Out:
#       Customer_ID  Age  Gender Item_Purchased     Category  \
# 0               1   55       1         Blouse     Clothing
# 1               2   19       1        Sweater     Clothing
# 2               3   50       1          Jeans     Clothing
# 3               4   21       1        Sandals     Footwear
# 4               5   45       1         Blouse     Clothing
# ...           ...  ...     ...            ...          ...
# 3895         3896   40       0         Hoodie     Clothing
# 3896         3897   52       0       Backpack  Accessories
# 3897         3898   46       0           Belt  Accessories
# 3898         3899   44       0          Shoes     Footwear
# 3899         3900   52       0        Handbag  Accessories
#
#       Purchase_Amount_USD       Location Size      Color  Season  \
# 0                      53       Kentucky    L       Gray  Winter
# 1                      64          Maine    L     Maroon  Winter
# ...

# %%
df['Discount_Applied'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
df['Discount_Applied'] = df['Discount_Applied'].str.strip().str.lower()
df['Discount_Applied'] = df['Discount_Applied'].map({'yes':1, 'no': 0})
df
# Out:
#       Customer_ID  Age  Gender Item_Purchased     Category  \
# 0               1   55       1         Blouse     Clothing
# 1               2   19       1        Sweater     Clothing
# 2               3   50       1          Jeans     Clothing
# 3               4   21       1        Sandals     Footwear
# 4               5   45       1         Blouse     Clothing
# ...           ...  ...     ...            ...          ...
# 3895         3896   40       0         Hoodie     Clothing
# 3896         3897   52       0       Backpack  Accessories
# 3897         3898   46       0           Belt  Accessories
# 3898         3899   44       0          Shoes     Footwear
# 3899         3900   52       0        Handbag  Accessories
#
#       Purchase_Amount_USD       Location Size      Color  Season  \
# 0                      53       Kentucky    L       Gray  Winter
# 1                      64          Maine    L     Maroon  Winter
# ...

# %%
category_summary=df.groupby('Category')['Purchase_Amount_USD'].agg(['count', 'sum', 'mean']).sort_values(by='count')

# %%
# Plot Purchase Count by Category
plt.figure(figsize=(5,6))
colors=['red' if x < 500 else 'blue' for x in category_summary['count']]  
sns.barplot(x=category_summary.index, y=category_summary['count'],palette=colors)
plt.title('Purchase Count by Product Category')
plt.show()
# Out:
# C:\Users\91984\AppData\Local\Temp\ipykernel_4404\3566474228.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=category_summary.index, y=category_summary['count'],palette=colors)

# %%
# Step 1: Create age groups
df['Age_Group'] = pd.cut(df['Age'],
                         bins=[17, 25, 35, 50, 100],
                         labels=['18-25', '26-35', '36-50', '50+'])

# Step 2: Standardize payment method values
df['Payment_Method'] = df['Payment_Method'].astype(str).str.strip().str.lower()

# Step 3: Filter only credit card payments
card_df = df[df['Payment_Method'] == 'credit card']

# Step 4: Group by Age Group
age_spending = card_df.groupby('Age_Group')['Purchase_Amount_USD'].sum()

plt.figure(figsize=(8, 6))
age_spending.plot(kind='bar', color='skyblue')
plt.title('Credit Card Spending by Age Group')
plt.xlabel('Age Group')
plt.ylabel('Total Purchase Amount (USD)')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\91984\AppData\Local\Temp\ipykernel_4404\3645436779.py:13: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   age_spending = card_df.groupby('Age_Group')['Purchase_Amount_USD'].sum()

# %%
df['Season'] = df['Season'].astype(str).str.strip().str.lower()
season_spending = card_df.groupby('Season')['Purchase_Amount_USD'].sum()

plt.figure(figsize=(8, 6))
season_spending.plot(kind='bar', color='coral')
plt.title('Credit Card Spending by Season')
plt.xlabel('Season')
plt.ylabel('Total Purchase Amount (USD)')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
location_spending = card_df.groupby('Location')['Purchase_Amount_USD'].sum().sort_values(ascending=False)

plt.figure(figsize=(10, 8))
location_spending.plot(kind='barh', color='lightgreen')
plt.title('Credit Card Spending by Location')
plt.xlabel('Total Purchase Amount (USD)')
plt.ylabel('Location')
plt.tight_layout()
plt.show()

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import seaborn as sns


# Step 1: Data Cleaning
df['Discount_Applied'] = df['Discount_Applied'].str.strip().str.lower().map({'yes': 1, 'no': 0})
df['Subscription_Status'] = df['Subscription_Status'].str.strip().str.lower().map({'yes': 1, 'no': 0})
df['Promo_Code_Used'] = df['Promo_Code_Used'].str.strip().str.lower().map({'yes': 1, 'no': 0})
df['Gender'] = df['Gender'].str.strip().str.lower().map({'male': 1, 'female': 0})

# Step 2: Select features for clustering
features = df[['Age', 'Purchase_Amount_USD', 'Previous_Purchases', 'Review_Rating',
               'Subscription_Status', 'Discount_Applied', 'Promo_Code_Used', 'Gender']]

# Drop any missing values
features = features.dropna()

# Step 3: Normalize the data
scaler = StandardScaler()
features_scaled = scaler.fit_transform(features)

# Step 4: Apply K-Means Clustering
kmeans = KMeans(n_clusters=3, random_state=42)
clusters = kmeans.fit_predict(features_scaled)

# Add cluster labels back to the dataframe
df['Cluster'] = clusters

# Step 5: Analyze Cluster Profiles
cluster_summary = df.groupby('Cluster')[['Age', 'Purchase_Amount_USD', 'Previous_Purchases',
                                         'Review_Rating', 'Subscription_Status',
                                         'Discount_Applied', 'Promo_Code_Used']].mean()

print("\n Cluster Profile Summary:")
print(cluster_summary)

# Step 6: Visualize Clusters using PCA
pca = PCA(n_components=2)
components = pca.fit_transform(features_scaled)

plt.figure(figsize=(8, 6))
sns.scatterplot(x=components[:, 0], y=components[:, 1], hue=clusters, palette='Set2', s=100)
plt.title('Customer Clusters (PCA Projection)')
plt.xlabel('PCA Component 1')
plt.ylabel('PCA Component 2')
plt.tight_layout()
plt.show()
# Out:
# 🧠 Cluster Profile Summary:
#                Age  Purchase_Amount_USD  Previous_Purchases  Review_Rating  \
# Cluster
# 0        44.000000            58.919872           25.166667       3.734936
# 1        44.010796            60.130454           25.056230       3.757715
# 2        44.230769            59.491928           26.084520       3.742450
#
#          Subscription_Status  Discount_Applied  Promo_Code_Used
# Cluster
# 0                        0.0               1.0              1.0
# 1                        0.0               0.0              0.0
# 2                        1.0               1.0              1.0
